# %%
import pandas as pd
import numpy as np
from joblib import dump, load
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

df = pd.read_csv("./RUvideos.csv")

# %%
df
# Out:
#           video_id trending_date  \
# 0      gDuslQ9avLc      17.14.11
# 1      AOCJIFEA_jE      17.14.11
# 2      VAWNQDgwwOM      17.14.11
# 3      gknkFwKQfHg      17.14.11
# 4      3sYvZcwzZr8      17.14.11
# ...            ...           ...
# 40734  OMmR9THjVKM      18.14.06
# 40735  tX7p7NtNVDE      18.14.06
# 40736  KAyj5Xm1C64      18.14.06
# 40737  4PiSLIrsSiY      18.14.06
# 40738  Ehy5foVfKOE      18.14.06
#
#                                                    title   channel_title  \
# 0                        Захар и Полина учатся экономить       Т—Ж БОГАЧ
# 1                       Биржа Мемов #29. Большой выпуск    Druzhko Show
# 2                           ХАЙП КЭМП - СВОЙ СРЕДИ ЧУЖИХ            Юлик
# 3                             Сочная кесадилья с курицей        Hochland
# 4                  КЛИПЫ РОДИТЕЛЕЙ НА ШКОЛЬНЫЙ ВЫПУСКНОЙ        Совергон
# ...                                                  ...             ...
# ...

# %%
df.describe()
# Out:
#         category_id         views         likes       dislikes  comment_count
# count  40739.000000  4.073900e+04  4.073900e+04   40739.000000   40739.000000
# mean      20.261936  2.407152e+05  1.243522e+04    1475.199612    1775.231179
# std        7.890955  9.345111e+05  6.038280e+04    8582.480809   11275.028305
# min        1.000000  1.170000e+02  0.000000e+00       0.000000       0.000000
# 25%       20.000000  2.258750e+04  4.025000e+02      31.000000      73.000000
# 50%       22.000000  6.631600e+04  1.880000e+03     128.000000     309.000000
# 75%       25.000000  1.951310e+05  7.791000e+03     586.000000    1107.000000
# max       43.000000  6.279639e+07  4.470923e+06  884967.000000  905925.000000

# %%
X = df.title
y = df.likes

transformer = TfidfVectorizer()
X_tf = transformer.fit_transform(X)
#df.description = transformer.fit_transform(df.description)

# %%
X_tf
# Out:
# <40739x55511 sparse matrix of type '<class 'numpy.float64'>'
# 	with 301101 stored elements in Compressed Sparse Row format>

# %%
from sklearn import linear_model
from sklearn.model_selection import cross_val_score

reg = linear_model.LinearRegression()
#score = cross_val_score(reg, X_tf, y, cv=3)

# %%
reg.fit(X_tf, y)
# Out:
# LinearRegression()

# %%
data = ''
data_tf = transformer.transform([data])
score = int(reg.predict(data_tf)[0])
if (score > 10**6):
    print(scope // 10**6, 'М')
elif (score > 10**3):
    print(score // 10**3, 'К')
else:
    print(score)
# Out:
# 37 К
